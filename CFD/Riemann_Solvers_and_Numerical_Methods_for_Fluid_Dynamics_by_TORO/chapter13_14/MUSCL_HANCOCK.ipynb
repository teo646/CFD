# %% [markdown]
# # 13.4.2 The MUSCL–Hancock Method (MHM)
#
# <img src="images/image.png" width="600">
#
# # 14.4.2 A Variant of the Scheme
#
# <img src="images/image copy.png" width="600">

# %% [markdown]
# #### 13, 14장에서는 고차화 방식 3가지를 설명하는데 그 중 하나가 MUSCL_HANCOCK 방식이다. 기존 방식은 local riemann problem에서 right state와 left state를 인접한 두 셀의 값을 그대로 이용한다. 하지만 이 방식은 선형 보간을 통하여 셀 경계에서의 값을 만들어서 사용한다.
